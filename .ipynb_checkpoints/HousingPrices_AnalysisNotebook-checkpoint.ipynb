# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
from numerize.numerize import numerize as nz # Easy number formatting
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator,StrMethodFormatter, FuncFormatter, AutoMinorLocator)

# %%
# Load All Homes CSV file
Neighborhood_Zhvi_AllHomes = pd.read_csv('Data/Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv',index_col=[5,7,8,6,2])
Neighborhood_Zhvi_2bedroom = pd.read_csv('Data/Neighborhood_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv',index_col=[5,7,8,6,2])
Neighborhood_Zhvi_3bedroom = pd.read_csv('Data/Neighborhood_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv',index_col=[5,7,8,6,2])

# %%
Neighborhood_Zhvi_AllHomes.head()
# Out:
#                                                                                               RegionID  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             112345
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     274772
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             192689
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side      270957
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    118208
#
#                                                                                               SizeRank  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale                  0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas          1
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise                  2
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side           3
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles         4
#
#                                                                                                 RegionType  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale           neighborhood
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas   neighborhood
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise           neighborhood
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side    neighborhood
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles  neighborhood
#
#                                                                                              StateName  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale                 AZ
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas         TX
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise                 NV
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side          NY
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles        CA
#
#                                                                                               2000-01-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale              80455.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     152673.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             149371.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side      556119.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    154450.0
#
#                                                                                               2000-02-29  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale              80779.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     152769.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             149331.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side      560092.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    154336.0
#
#                                                                                               2000-03-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale              81179.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     152799.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             149651.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side      564031.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    154589.0
#
#                                                                                               2000-04-30  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale              82046.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     153052.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             150278.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side      572508.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    155245.0
#
#                                                                                               2000-05-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale              82916.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     153227.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             151012.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side      583165.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    156260.0
#
#                                                                                               2000-06-30  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale              83671.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     153532.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             151644.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side      595145.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    157175.0
#
#                                                                                               ...  \
# State Metro                                 CountyName         City        RegionName         ...
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale           ...
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas   ...
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise           ...
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side    ...
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles  ...
#
#                                                                                               2022-01-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             281593.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     422382.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             368924.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1363520.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    678662.0
#
#                                                                                               2022-02-28  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             287389.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     431237.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             377982.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1374652.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    687018.0
#
#                                                                                               2022-03-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             290499.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     440238.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             388412.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1390012.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    698856.0
#
#                                                                                               2022-04-30  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             295505.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     451895.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             396332.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1405686.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    712335.0
#
#                                                                                               2022-05-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             301483.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     460428.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             404093.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1420269.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    723039.0
#
#                                                                                               2022-06-30  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             307557.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     468627.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             409307.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1428335.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    724349.0
#
#                                                                                               2022-07-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             307484.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     471548.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             410903.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1430833.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    723777.0
#
#                                                                                               2022-08-31  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             301056.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     473142.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             408400.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1431655.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    713166.0
#
#                                                                                               2022-09-30  \
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             293820.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     467978.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             403195.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1431973.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    703488.0
#
#                                                                                               2022-10-31
# State Metro                                 CountyName         City        RegionName
# AZ    Phoenix-Mesa-Chandler, AZ             Maricopa County    Phoenix     Maryvale             288391.0
# TX    Dallas-Fort Worth-Arlington, TX       Dallas County      Dallas      Northeast Dallas     465173.0
# NV    Las Vegas-Henderson-Paradise, NV      Clark County       Las Vegas   Paradise             396789.0
# NY    New York-Newark-Jersey City, NY-NJ-PA New York County    New York    Upper East Side     1431119.0
# CA    Los Angeles-Long Beach-Anaheim, CA    Los Angeles County Los Angeles South Los Angeles    691565.0
#
# [5 rows x 278 columns]

# %%
lastcol = Neighborhood_Zhvi_AllHomes.columns[-1] #Define last column to use for current prices
LastPriceDF = Neighborhood_Zhvi_AllHomes.iloc[:,[-1]].rename(columns={lastcol:'AllHomes'})
LastPriceDF.join(
    Neighborhood_Zhvi_2bedroom.iloc[:,[-1]].rename(columns={lastcol:'2bed'})).join(
    Neighborhood_Zhvi_3bedroom.iloc[:,[-1]].rename(columns={lastcol:'3bed'})
)
# Out:
#                                                                       AllHomes  \
# State Metro          CountyName        City       RegionName
# AK    Anchorage, AK  Anchorage Borough Anchorage  Abbott Loop         397271.0
#                                                   Airport Heights     337458.0
#                                                   Basher              878846.0
#                                                   Bayshore-Klatt      484069.0
#                                                   Bear Valley         525629.0
# ...                                                                        ...
# WV    Morgantown, WV Monongalia County Morgantown Woodburn            173069.0
# WY    Jackson, WY-ID Teton County      Jackson    Hoback             1661982.0
#                                                   Rafter J Ranch     1245629.0
#                                                   South Park         2434066.0
#                                        Wilson     Moose Wilson Road  2004215.0
#
#                                                                           2bed  \
# State Metro          CountyName        City       RegionName
# AK    Anchorage, AK  Anchorage Borough Anchorage  Abbott Loop         271805.0
#                                                   Airport Heights     287401.0
#                                                   Basher                   NaN
#                                                   Bayshore-Klatt      261980.0
#                                                   Bear Valley              NaN
# ...                                                                        ...
# WV    Morgantown, WV Monongalia County Morgantown Woodburn            150576.0
# WY    Jackson, WY-ID Teton County      Jackson    Hoback                   NaN
#                                                   Rafter J Ranch      903448.0
#                                                   South Park               NaN
#                                        Wilson     Moose Wilson Road  1152533.0
#
#                                                                           3bed
# State Metro          CountyName        City       RegionName
# AK    Anchorage, AK  Anchorage Borough Anchorage  Abbott Loop         402431.0
#                                                   Airport Heights     349382.0
#                                                   Basher              815809.0
#                                                   Bayshore-Klatt      471351.0
#                                                   Bear Valley         549434.0
# ...                                                                        ...
# WV    Morgantown, WV Monongalia County Morgantown Woodburn            187037.0
# WY    Jackson, WY-ID Teton County      Jackson    Hoback             1328982.0
#                                                   Rafter J Ranch     1326606.0
#                                                   South Park         1994319.0
#                                        Wilson     Moose Wilson Road  2500358.0
#
# [21499 rows x 3 columns]

# %%
Top5States = LastPriceDF.groupby(level='State').mean().sort_values(by=['AllHomes'],ascending=False).head(5)
Top5States.plot.barh(title='US ZHVI @ November 2022', grid=True, figsize=(14,7), width=0.9, linewidth=0.75, edgecolor=(0.1,0.5,1,1))
# Out:
# <AxesSubplot: title={'center': 'US ZHVI @ November 2022'}, ylabel='State'>

# %%
Top5States['AllHomes']
# Out:
# State
# WY    1.836473e+06
# CA    1.132883e+06
# HI    1.039707e+06
# WA    8.081824e+05
# DC    7.675188e+05
# Name: AllHomes, dtype: float64

# %%
def human_format(num, pos):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

# %%
def nice_axes(ax):
    ax.set_facecolor('.9')
    ax.tick_params(labelsize=8, length=0)
    ax.grid(True, axis='x', color='white')
    ax.set_axisbelow(True)
#     ax.xaxis.set_major_formatter(StrMethodFormatter('${x:,g}K'))
    ax.xaxis.set_major_formatter(FuncFormatter(nz))
    [spine.set_visible(False) for spine in ax.spines.values()]
    
fig, ax = plt.subplots(figsize=(5, 2.5), dpi=144)
colors = plt.cm.Accent(range(len(Top5States)))
y = Top5States.index
width = Top5States['AllHomes'].values
ax.barh(y=y, width=width, color=colors);
nice_axes(ax)

# %%
LastPriceDF.loc[Top5States.index]
# Out:
#                                                                                                         AllHomes
# State Metro                                        CountyName           City        RegionName
# WY    Jackson, WY-ID                               Teton County         Jackson     Rafter J Ranch     1245629.0
#                                                                                     South Park         2434066.0
#                                                                         Wilson      Moose Wilson Road  2004215.0
#                                                                         Jackson     Hoback             1661982.0
# CA    Los Angeles-Long Beach-Anaheim, CA           Los Angeles County   Los Angeles South Los Angeles   691565.0
# ...                                                                                                          ...
# DC    Washington-Arlington-Alexandria, DC-VA-MD-WV District of Columbia Washington  Hillcrest           681471.0
#                                                                                     Hawthorne          1442131.0
#                                                                                     Tenleytown         1179243.0
#                                                                                     Penn Branch         626859.0
#                                                                                     Foxhall            1323109.0
#
# [2898 rows x 1 columns]

# %%
LastPriceDF.loc[Top5States.index].boxplot(by='State',figsize=(11,6),grid=True)
# Out:
# <AxesSubplot: title={'center': 'AllHomes'}, xlabel='[State]'>

# %%
LastPriceDF.groupby(level='State').describe().sort_values(by=('AllHomes','mean'),ascending=False).head().applymap(nz)
# Out:
#       AllHomes
#          count     mean      std      min      25%      50%      75%     max
# State
# WY           4    1.84M  504.91K    1.25M    1.56M    1.83M    2.11M   2.43M
# CA       2.21K    1.13M   885.9K  194.28K  603.22K  842.78K    1.37M  12.18M
# HI           5    1.04M   566.6K  422.15K     491K    1.15M    1.44M    1.7M
# WA         562  808.18K  457.42K  274.38K  497.55K  681.17K  956.32K   3.68M
# DC         120  767.52K  479.59K  154.96K  454.25K  619.42K  839.19K   3.25M

# %%
Top5Cities = LastPriceDF.groupby(level='Metro').mean().sort_values(by=['AllHomes'],ascending=False).head(5)
Top5Cities.plot.barh(title='US ZHVI @ November 2022', grid=True, figsize=(14,7), width=0.9, linewidth=0.75, edgecolor=(0.1,0.5,1,1))
# Out:
# <AxesSubplot: title={'center': 'US ZHVI @ November 2022'}, ylabel='Metro'>

# %%
LastPriceDF.groupby(level='Metro').describe().sort_values(by=('AllHomes','mean'),ascending=False).head(10).applymap(nz)
# Out:
#                                        AllHomes                           \
#                                           count   mean      std      min
# Metro
# San Jose-Sunnyvale-Santa Clara, CA          100  2.63M    1.08M  909.68K
# Naples-Marco Island, FL                      23  2.29M    3.65M   344.5K
# Heber, UT                                    10  2.07M    1.36M  616.87K
# Crestview-Fort Walton Beach-Destin, FL        8  2.06M    2.14M  312.17K
# Santa Maria-Santa Barbara, CA                28  2.02M  934.76K    1.12M
# Jackson, WY-ID                                4  1.84M  504.91K    1.25M
# Key West, FL                                 11  1.52M  477.95K   875.5K
# Bremerton-Silverdale-Port Orchard, WA         9  1.51M  321.93K    1.04M
# San Francisco-Oakland-Berkeley, CA          493  1.48M  723.68K  456.45K
# Los Angeles-Long Beach-Anaheim, CA          506  1.32M    1.13M  328.44K
#
#
#                                             25%      50%    75%     max
# Metro
# San Jose-Sunnyvale-Santa Clara, CA        1.68M    2.64M  3.37M   5.05M
# Naples-Marco Island, FL                 689.06K    1.04M  1.68M  16.55M
# Heber, UT                                878.5K    1.94M  2.64M   4.79M
# Crestview-Fort Walton Beach-Destin, FL  327.58K  892.86K  4.03M   5.38M
# Santa Maria-Santa Barbara, CA             1.35M    1.83M  2.25M   5.13M
# Jackson, WY-ID                            1.56M    1.83M  2.11M   2.43M
# Key West, FL                              1.23M    1.42M   1.8M   2.48M
# Bremerton-Silverdale-Port Orchard, WA     1.25M    1.58M  1.68M    2.1M
# San Francisco-Oakland-Berkeley, CA       930.3K    1.34M  1.83M   4.99M
# Los Angeles-Long Beach-Anaheim, CA      779.52K    1.04M  1.46M  12.18M

# %%
LastPriceDF[LastPriceDF.index.get_level_values(1).isin(Top5Cities.index)].boxplot(by='Metro',figsize=(11,6),rot=25)
# Out:
# <AxesSubplot: title={'center': 'AllHomes'}, xlabel='[Metro]'>

# %%
# LastPriceDF[LastPriceDF.index.get_level_values(2) == 'San Diego County'].groupby(level='City').describe()
LastPriceDF[LastPriceDF.index.get_level_values(2) == 'San Diego County'].boxplot(by='City',figsize=(11,6))
# Out:
# <AxesSubplot: title={'center': 'AllHomes'}, xlabel='[City]'>

# %%
LastPriceDF[LastPriceDF.index.get_level_values(3) == 'San Diego'].sort_values(by=('AllHomes'),ascending=False).head(12).applymap(nz)
# Out:
#                                                                                             AllHomes
# State Metro                              CountyName       City      RegionName
# CA    San Diego-Chula Vista-Carlsbad, CA San Diego County San Diego North City                  2.6M
#                                                                     La Jolla                   2.43M
#                                                                     Sunset Cliffs              2.41M
#                                                                     Rancho Encantado           2.38M
#                                                                     Del Mar Heights            2.32M
#                                                                     Horton Plaza               2.27M
#                                                                     Wooded Area                2.22M
#                                                                     La Playa                   2.14M
#                                                                     Black Mountain Ranch       1.94M
#                                                                     Roseville - Fleet Ridge    1.89M
#                                                                     Carmel Valley              1.82M
#                                                                     Torrey Highlands            1.8M

# %% [markdown]
# ### One year ago compare

# %%
oneyearago = Neighborhood_Zhvi_AllHomes.columns[-13]
OYAPriceDF = Neighborhood_Zhvi_AllHomes.loc[:,[oneyearago]].rename(columns={oneyearago:'AllHomes'})

# %%
Top5States = OYAPriceDF.groupby(level='State').mean().sort_values(by=['AllHomes'],ascending=False).head(5)
Top5States.plot.barh(title='US ZHVI @ November 2022', grid=True, figsize=(14,7), width=0.9, linewidth=0.75, edgecolor=(0.1,0.5,1,1))
# Out:
# <AxesSubplot: title={'center': 'US ZHVI @ November 2022'}, ylabel='State'>

# %%
Top5Cities = OYAPriceDF.groupby(level='Metro').mean().sort_values(by=['AllHomes'],ascending=False).head(5)
Top5Cities.plot.barh(title='US ZHVI @ November 2022', grid=True, figsize=(14,7), width=0.9, linewidth=0.75, edgecolor=(0.1,0.5,1,1))
# Out:
# <AxesSubplot: title={'center': 'US ZHVI @ November 2022'}, ylabel='Metro'>

# %%
OYAPriceDF.groupby(level='Metro').describe().sort_values(by=('AllHomes','mean'),ascending=False).head(10).applymap(nz)
# Out:
#                                        AllHomes                           \
#                                           count   mean      std      min
# Metro
# San Jose-Sunnyvale-Santa Clara, CA           99  2.48M    1.04M   901.1K
# Santa Maria-Santa Barbara, CA                27  1.76M  759.15K  962.72K
# Naples-Marco Island, FL                      23  1.64M    2.63M  254.84K
# Crestview-Fort Walton Beach-Destin, FL        8   1.6M    1.64M  269.46K
# Jackson, WY-ID                                4  1.58M  441.58K    1.09M
# Heber, UT                                    10  1.54M  990.04K  447.51K
# San Francisco-Oakland-Berkeley, CA          487  1.45M  674.39K  534.29K
# Bremerton-Silverdale-Port Orchard, WA         9  1.32M  295.85K  900.76K
# Los Angeles-Long Beach-Anaheim, CA          491  1.24M     1.1M  300.52K
# Key West, FL                                 11  1.16M  345.29K  698.42K
#
#
#                                             25%      50%    75%     max
# Metro
# San Jose-Sunnyvale-Santa Clara, CA        1.55M    2.48M  3.16M      5M
# Santa Maria-Santa Barbara, CA             1.22M    1.56M  1.93M   4.28M
# Naples-Marco Island, FL                 505.98K  717.34K  1.18M  11.92M
# Crestview-Fort Walton Beach-Destin, FL  281.17K  677.93K  3.11M   4.12M
# Jackson, WY-ID                            1.32M    1.57M  1.84M   2.11M
# Heber, UT                               712.18K     1.4M  2.02M   3.53M
# San Francisco-Oakland-Berkeley, CA      942.52K    1.31M  1.77M   4.85M
# Bremerton-Silverdale-Port Orchard, WA     1.08M    1.38M  1.44M   1.87M
# Los Angeles-Long Beach-Anaheim, CA      742.89K  967.71K  1.37M  12.16M
# Key West, FL                             963.7K    1.08M  1.36M   1.85M

# %% [markdown]
# ## Time series analysis

# %%
zhvi_timeseries = Neighborhood_Zhvi_AllHomes.T
dates = pd.to_datetime(zhvi_timeseries.index, errors='coerce').dropna()
zhvi_timeseries = zhvi_timeseries.loc[dates.strftime("%Y-%m-%d")]
zhvi_timeseries.index = pd.to_datetime(zhvi_timeseries.index, errors='coerce').dropna()
zhvi_timeseries
# pd.to_datetime(Neighborhood_Zhvi_AllHomes.columns[4]).strftime("%Y-%m-%d")
# zhvi_timeseries.loc[dates.strftime("%Y-%m-%d")]
# Out:
# State                             AZ                              TX  \
# Metro      Phoenix-Mesa-Chandler, AZ Dallas-Fort Worth-Arlington, TX
# CountyName           Maricopa County                   Dallas County
# City                         Phoenix                          Dallas
# RegionName                  Maryvale                Northeast Dallas
# 2000-01-31                   80455.0                        152673.0
# 2000-02-29                   80779.0                        152769.0
# 2000-03-31                   81179.0                        152799.0
# 2000-04-30                   82046.0                        153052.0
# 2000-05-31                   82916.0                        153227.0
# ...                              ...                             ...
# 2022-06-30                  307557.0                        468627.0
# 2022-07-31                  307484.0                        471548.0
# 2022-08-31                  301056.0                        473142.0
# 2022-09-30                  293820.0                        467978.0
# 2022-10-31                  288391.0                        465173.0
#
# State                                    NV  \
# Metro      Las Vegas-Henderson-Paradise, NV
# CountyName                     Clark County
# City                              Las Vegas
# RegionName                         Paradise
# 2000-01-31                         149371.0
# 2022-09-30                         356024.0
# 2022-10-31                         350433.0
#
# State                                         NY  ...  \
# Metro      New York-Newark-Jersey City, NY-NJ-PA  ...
# CountyName                          Kings County  ...
# City                                    New York  ...
# RegionName                    Bedford-Stuyvesant  ...
# 2000-01-31                              166040.0  ...
# 2000-02-29                              167540.0  ...
# 2000-03-31                              168402.0  ...
# 2000-04-30                              170759.0  ...
# 2000-05-31                              172372.0  ...
# ...                                          ...  ...
# 2022-06-30                             1074576.0  ...
# 2022-07-31                             1082753.0  ...
# 2022-08-31                             1088867.0  ...
# 2022-09-30                             1091646.0  ...
# 2022-10-31                             1092558.0  ...
#
# State                                        TX  \
# Metro      Houston-The Woodlands-Sugar Land, TX
# CountyName                     Fort Bend County
# City                                 Sugar Land
# RegionName                               Oxford
# 2000-01-31                             220718.0
# 2000-02-29                             223614.0
# 2000-03-31                             226990.0
# 2000-04-30                             231983.0
# 2000-05-31                             234860.0
# ...                                         ...
# 2022-06-30                             498126.0
# 2022-07-31                             500220.0
# 2022-08-31                             498251.0
# 2022-09-30                             496214.0
# 2022-10-31                             495295.0
#
# State                                        GA             AL  \
# Metro      Atlanta-Sandy Springs-Alpharetta, GA Huntsville, AL
# CountyName                       Forsyth County Madison County
# City                                    Cumming     Huntsville
# RegionName                             Deerwood    Jacobs Cove
# 2000-01-31                             160146.0            NaN
# 2000-02-29                             161218.0            NaN
# 2000-03-31                             161730.0            NaN
# 2000-04-30                             163398.0            NaN
# 2000-05-31                             164356.0            NaN
# ...                                         ...            ...
# 2022-06-30                             322558.0       414838.0
# 2022-07-31                             324806.0       418840.0
# 2022-08-31                             324374.0       421345.0
# 2022-09-30                             323654.0       423316.0
# 2022-10-31                             321945.0       425356.0
#
# State                                   TX                            \
# Metro      Dallas-Fort Worth-Arlington, TX
# CountyName                  Tarrant County
# City                            Fort Worth
# RegionName                     Bonds Ranch Villages of Sunset Pointe
# 2000-01-31                             NaN                       NaN
# 2000-02-29                             NaN                       NaN
# 2000-03-31                             NaN                       NaN
# 2000-04-30                             NaN                       NaN
# 2000-05-31                             NaN                       NaN
# ...                                    ...                       ...
# 2022-06-30                        593895.0                  352996.0
# 2022-07-31                        596966.0                  354074.0
# 2022-08-31                        591325.0                  350238.0
# 2022-09-30                        590279.0                  346676.0
# 2022-10-31                        590747.0                  343481.0
#
# State                        OH               IN  \
# Metro      Canton-Massillon, OH   Fort Wayne, IN
# CountyName         Stark County     Allen County
# City                     Canton       Fort Wayne
# RegionName   Georgeview Estates Trier Ridge Park
# 2000-01-31                  NaN              NaN
# 2000-02-29                  NaN              NaN
# 2000-03-31                  NaN              NaN
# 2000-04-30                  NaN              NaN
# 2000-05-31                  NaN              NaN
# ...                         ...              ...
# 2022-06-30             165528.0         179815.0
# 2022-07-31             168020.0         180591.0
# 2022-08-31             169119.0         181229.0
# 2022-09-30             168411.0         182095.0
# 2022-10-31             167097.0         182546.0
#
# State                                   TX              CA                NC
# Metro      Dallas-Fort Worth-Arlington, TX     Visalia, CA  Fayetteville, NC
# CountyName                   Dallas County   Tulare County Cumberland County
# City                               Garland         Visalia      Fayetteville
# RegionName                        Lakeview River Run Ranch Cliffdale Estates
# 2000-01-31                        103526.0             NaN               NaN
# 2000-02-29                        103643.0        113968.0               NaN
# 2000-03-31                        104232.0        113982.0               NaN
# 2000-04-30                        104429.0        113870.0               NaN
# 2000-05-31                        104629.0        114095.0               NaN
# ...                                    ...             ...               ...
# 2022-06-30                        345515.0        359326.0               NaN
# 2022-07-31                        347626.0        357506.0               NaN
# 2022-08-31                        349624.0        354977.0               NaN
# 2022-09-30                        347118.0        355659.0          179115.0
# 2022-10-31                        347036.0        356577.0          181933.0
#
# [274 rows x 21491 columns]

# %%
set(zhvi_timeseries.columns.get_level_values(2).values)
# Out:
# {'Ada County',
#  'Adams County',
#  'Aiken County',
#  'Alachua County',
#  'Alameda County',
#  'Albany County',
#  'Alexandria City',
#  'Allegany County',
#  'Allegheny County',
#  'Allen County',
#  'Anchorage Borough',
#  'Anne Arundel County',
#  'Arapahoe County',
#  'Archer County',
#  'Arlington County',
#  'Auglaize County',
#  'Avery County',
#  'Baltimore City',
#  'Baltimore County',
#  'Barnstable County',
#  'Barry County',
#  'Bay County',
#  'Beaufort County',
#  'Bell County',
#  'Bennington County',
#  'Benton County',
#  'Berkeley County',
#  'Berkshire County',
#  'Bernalillo County',
#  'Berrien County',
#  'Bexar County',
#  'Black Hawk County',
#  'Blair County',
#  'Boone County',
#  'Boulder County',
#  'Bowie County',
#  'Brazoria County',
#  'Brazos County',
#  'Brevard County',
#  'Bristol County',
#  'Bronx County',
#  'Broomfield County',
#  'Broward County',
#  'Brown County',
#  'Bucks County',
#  'Burlington County',
#  'Butler County',
#  'Butte County',
#  'Cabarrus County',
#  'Cache County',
#  'Caddo Parish',
#  'Caldwell County',
#  'Calhoun County',
#  'Callaway County',
#  'Cambria County',
#  'Camden County',
#  'Cameron County',
#  'Canyon County',
#  'Cape May County',
#  'Carroll County',
#  'Cass County',
#  'Catawba County',
#  'Catoosa County',
#  'Charleston County',
#  'Charlottesville City',
#  'Chatham County',
#  'Chesapeake City',
#  'Chester County',
#  'Citrus County',
#  'Clackamas County',
#  'Clallam County',
#  'Clark County',
#  'Clarke County',
#  'Clatsop County',
#  'Clay County',
#  'Clayton County',
#  'Clermont County',
#  'Cleveland County',
#  'Cobb County',
#  'Coconino County',
#  'Collier County',
#  'Collin County',
#  'Columbia County',
#  'Contra Costa County',
#  'Cook County',
#  'Cowlitz County',
#  'Craighead County',
#  'Craven County',
#  'Cumberland County',
#  'Cuyahoga County',
#  'Dakota County',
#  'Dallas County',
#  'Dane County',
#  'Darlington County',
#  'Dauphin County',
#  'Davidson County',
#  'Davie County',
#  'Daviess County',
#  'DeKalb County',
#  'Dekalb County',
#  'Delaware County',
#  'Denton County',
#  'Denver County',
#  'Deschutes County',
#  'District of Columbia',
#  'Dona Ana County',
#  'Douglas County',
#  'DuPage County',
#  'Dubuque County',
#  'Durham County',
#  'Dutchess County',
#  'Duval County',
#  'East Baton Rouge Parish',
#  'Eaton County',
#  'Eau Claire County',
#  'Ector County',
#  'Edgefield County',
#  'El Dorado County',
#  'El Paso County',
#  'Elkhart County',
#  'Ellis County',
#  'Erie County',
#  'Escambia County',
#  'Essex County',
#  'Fairbanks North Star Borough',
#  'Fairfax City',
#  'Fairfax County',
#  'Fairfield County',
#  'Fayette County',
#  'Floyd County',
#  'Forrest County',
#  'Forsyth County',
#  'Fort Bend County',
#  'Franklin County',
#  'Fredericksburg City',
#  'Fresno County',
#  'Fulton County',
#  'Gallatin County',
#  'Garland County',
#  'Geauga County',
#  'Genesee County',
#  'Grafton County',
#  'Grand Traverse County',
#  'Grant County',
#  'Greene County',
#  'Greenville County',
#  'Gregg County',
#  'Guilford County',
#  'Hamilton County',
#  'Hampden County',
#  'Hampshire County',
#  'Hampton City',
#  'Harris County',
#  'Harrison County',
#  'Harrisonburg City',
#  'Hartford County',
#  'Hays County',
#  'Henderson County',
#  'Hennepin County',
#  'Henrico County',
#  'Hernando County',
#  'Hidalgo County',
#  'Hillsborough County',
#  'Hinds County',
#  'Honolulu County',
#  'Hood County',
#  'Horry County',
#  'Houston County',
#  'Howard County',
#  'Hudson County',
#  'Humboldt County',
#  'Hunt County',
#  'Indian River County',
#  'Ingham County',
#  'Iredell County',
#  'Jackson County',
#  'Jefferson County',
#  'Jefferson Parish',
#  'Johnson County',
#  'Jones County',
#  'Juneau Borough',
#  'Kalamazoo County',
#  'Kanawha County',
#  'Kane County',
#  'Kaufman County',
#  'Kendall County',
#  'Kenosha County',
#  'Kent County',
#  'Kern County',
#  'King County',
#  'Kings County',
#  'Kitsap County',
#  'Knox County',
#  'La Crosse County',
#  'Lackawanna County',
#  'Lake County',
#  'Lamar County',
#  'Lancaster County',
#  'Lane County',
#  'Larimer County',
#  'Lee County',
#  'Leelanau County',
#  'Lehigh County',
#  'Leon County',
#  'Lewis and Clark County',
#  'Lexington County',
#  'Lincoln County',
#  'Linn County',
#  'Litchfield County',
#  'Los Angeles County',
#  'Lowndes County',
#  'Lubbock County',
#  'Lucas County',
#  'Luzerne County',
#  'Macomb County',
#  'Madison County',
#  'Mahoning County',
#  'Manatee County',
#  'Marathon County',
#  'Maricopa County',
#  'Marin County',
#  'Marion County',
#  'Marquette County',
#  'Martin County',
#  'Mason County',
#  'Matanuska Susitna Borough',
#  'McCracken County',
#  'McLennan County',
#  'Mecklenburg County',
#  'Merced County',
#  'Mercer County',
#  'Merrimack County',
#  'Mesa County',
#  'Miami-Dade County',
#  'Middlesex County',
#  'Midland County',
#  'Milwaukee County',
#  'Minnehaha County',
#  'Missoula County',
#  'Mobile County',
#  'Monmouth County',
#  'Monongalia County',
#  'Monroe County',
#  'Monterey County',
#  'Montgomery County',
#  'Moore County',
#  'Multnomah County',
#  'Murray County',
#  'Muscogee County',
#  'Napa County',
#  'Nassau County',
#  'New Castle County',
#  'New Hanover County',
#  'New Haven County',
#  'New London County',
#  'New York County',
#  'Newport County',
#  'Newport News City',
#  'Newton County',
#  'Niagara County',
#  'Norfolk City',
#  'Norfolk County',
#  'Northampton County',
#  'Nueces County',
#  'Oakland County',
#  'Ocean County',
#  'Okaloosa County',
#  'Oklahoma County',
#  'Olmsted County',
#  'Onondaga County',
#  'Orange County',
#  'Orleans Parish',
#  'Osage County',
#  'Osceola County',
#  'Ottawa County',
#  'Ouachita Parish',
#  'Outagamie County',
#  'Palm Beach County',
#  'Parker County',
#  'Pasco County',
#  'Passaic County',
#  'Payne County',
#  'Peoria County',
#  'Philadelphia County',
#  'Pierce County',
#  'Pima County',
#  'Pinellas County',
#  'Pitt County',
#  'Placer County',
#  'Platte County',
#  'Plumas County',
#  'Plymouth County',
#  'Polk County',
#  'Portage County',
#  'Porter County',
#  'Portsmouth City',
#  'Pottawattamie County',
#  'Power County',
#  'Prince Georges County',
#  'Prince William County',
#  'Providence County',
#  'Pueblo County',
#  'Pulaski County',
#  'Putnam County',
#  'Queens County',
#  'Racine County',
#  'Ralls County',
#  'Ramsey County',
#  'Rensselaer County',
#  'Richland County',
#  'Richmond City',
#  'Richmond County',
#  'Riverside County',
#  'Roanoke City',
#  'Roanoke County',
#  'Rock Island County',
#  'Rockingham County',
#  'Rockland County',
#  'Rockwall County',
#  'Rutherford County',
#  'Rutland County',
#  'Sacramento County',
#  'Saginaw County',
#  'Saint Charles County',
#  'Saint Clair County',
#  'Saint Johns County',
#  'Saint Joseph County',
#  'Saint Louis City',
#  'Saint Louis County',
#  'Saint Lucie County',
#  'Salem County',
#  'Salt Lake County',
#  'San Bernardino County',
#  'San Diego County',
#  'San Francisco County',
#  'San Joaquin County',
#  'San Mateo County',
#  'Sandoval County',
#  'Sangamon County',
#  'Santa Barbara County',
#  'Santa Clara County',
#  'Santa Fe County',
#  'Sarasota County',
#  'Schenectady County',
#  'Scott County',
#  'Sedgwick County',
#  'Seminole County',
#  'Sequatchie County',
#  'Shawnee County',
#  'Shelby County',
#  'Sherburne County',
#  'Skagit County',
#  'Smith County',
#  'Snohomish County',
#  'Solano County',
#  'Somerset County',
#  'Sonoma County',
#  'Spartanburg County',
#  'Spencer County',
#  'Spokane County',
#  'Stark County',
#  'Stearns County',
#  'Story County',
#  'Suffolk County',
#  'Summit County',
#  'Sussex County',
#  'Tarrant County',
#  'Taylor County',
#  'Teton County',
#  'Thurston County',
#  'Tippecanoe County',
#  'Tolland County',
#  'Tom Green County',
#  'Tompkins County',
#  'Travis County',
#  'Tulare County',
#  'Tulsa County',
#  'Tuscaloosa County',
#  'Union County',
#  'Utah County',
#  'Val Verde County',
#  'Vanderburgh County',
#  'Ventura County',
#  'Vermilion County',
#  'Virginia Beach City',
#  'Volusia County',
#  'Wake County',
#  'Walton County',
#  'Walworth County',
#  'Ward County',
#  'Warren County',
#  'Wasatch County',
#  'Washington County',
#  'Washoe County',
#  'Washtenaw County',
#  'Watauga County',
#  'Waukesha County',
#  'Wayne County',
#  'Webb County',
#  'Weber County',
#  'Westchester County',
#  'Westmoreland County',
#  'Whatcom County',
#  'Wicomico County',
#  'Will County',
#  'Williamson County',
#  'Windham County',
#  'Windsor County',
# 2022-08-31  398806.573980  676426.072000  440573.893453  299339.2
# 2022-09-30  396951.562779  674196.032000  440581.154534  302674.8
# 2022-10-31  397076.140184  669158.704000  440658.690446  305202.0
#
# State                  WA             WI             WV         WY
# 2000-01-31  230994.901124  123538.660305   88735.833333        NaN
# 2000-02-29  232127.611236  123828.791822   88846.833333        NaN
# 2000-03-31  233085.238202  123564.099265   89072.166667        NaN
# 2000-04-30  234854.869663  123901.301471   89400.166667        NaN
# 2000-05-31  235686.682927  124675.278388   89406.750000        NaN
# ...                   ...            ...            ...        ...
# 2022-06-30  827984.461538  265510.056306  153111.333333  1766275.0
# 2022-07-31  821897.078712  266070.164414  153755.200000  1775326.5
# 2022-08-31  814960.032143  266528.563063  154861.800000  1790026.5
# 2022-09-30  811535.605357  266715.643498  156218.133333  1801665.5
# 2022-10-31  808182.444840  268429.841518  157916.266667  1836473.0
#
# [274 rows x 51 columns]

# %%
zhvi_timeseries.sort_values(by=zhvi_timeseries.index[-1],axis=1,ascending=False).iloc[-5:,:5].applymap(nz)
# Out:
# State                           FL                                 CA  \
# Metro      Naples-Marco Island, FL Los Angeles-Long Beach-Anaheim, CA
# CountyName          Collier County                 Los Angeles County
# City                        Naples                      Beverly Hills
# RegionName              Port Royal              Beverly Hills Gateway
# 2022-06-30                  15.97M                              12.8M
# 2022-07-31                  16.29M                             12.68M
# 2022-08-31                  16.57M                              12.5M
# 2022-09-30                  16.57M                             12.35M
# 2022-10-31                  16.55M                             12.18M
#
# State                                                                       FL
# Metro                                  Miami-Fort Lauderdale-Pompano Beach, FL
# CountyName                                                   Palm Beach County
# City                                                                   Jupiter
# RegionName Trousdale Estates The Flats                             Bear's Club
# 2022-06-30            10.89M    10.46M                                   8.25M
# 2022-07-31            10.89M    10.44M                                   8.43M
# 2022-08-31            10.91M    10.31M                                   8.56M
# 2022-09-30            10.93M     10.2M                                   8.72M
# 2022-10-31            10.85M    10.03M                                   8.86M

# %%
zhvi_timeseries.mean(axis=1).plot(grid = True,
        style = "-o",
        figsize = (14,7),
        linewidth = 0.9)
# Out:
# <AxesSubplot: >

# %%
zhvi_timeseries.groupby(level='State', axis=1).mean().plot(grid = True,
#         style = "-o",
        figsize = (14,7),
        linewidth = 0.9)
# Out:
# <AxesSubplot: >

# %%
cols_plot = Top5States.index.values
axes = zhvi_timeseries[cols_plot].groupby(level='State',axis=1).mean().dropna().plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Prices')

# %%
zhvi_timeseries[cols_plot].groupby(level='State',axis=1).mean().dropna().applymap(nz)
# Out:
# State            CA       DC       HI       WA       WY
# 2009-06-30  503.46K  491.98K  697.99K  345.97K  991.51K
# 2009-07-31  501.31K  488.62K  692.09K  343.73K  976.46K
# 2009-08-31  496.32K   484.9K  686.15K  341.46K  970.13K
# 2009-09-30   492.9K  480.89K  676.28K  339.62K  953.35K
# 2009-10-31  492.11K  476.43K  664.54K  338.56K  944.85K
# ...             ...      ...      ...      ...      ...
# 2022-06-30    1.17M  775.24K    1.05M  827.98K    1.77M
#
# State                VA                          IN             MI
# Metro       Roanoke, VA South Bend-Mishawaka, IN-MI    Saginaw, MI
# CountyName Roanoke City         Saint Joseph County Saginaw County
# City            Roanoke                  South Bend        Saginaw
# RegionName      Belmont              Near Northwest      Northeast
# 2021-11-30    -0.016191                    0.018483       0.001002
# 2021-12-31    -0.000857                    0.025127       0.040224
# 2022-01-31     0.004811                    0.031649       0.038834
# 2022-02-28     0.006809                    0.028831       0.025273
# 2022-03-31     0.010777                    0.015402       0.017327
# 2022-04-30     0.016329                    0.006797       0.025394
# 2022-05-31     0.011689                    0.012630       0.010486
# 2022-06-30     0.028019                    0.008723       0.000650
# 2022-07-31     0.014713                    0.022711      -0.006204
# 2022-08-31     0.041459                    0.030856       0.025210
# 2022-09-30     0.031274                    0.057216       0.049210
# 2022-10-31     0.063717                    0.057722       0.057460

# %%
zhvi_timeseries_pct[['WA']]
# zhvi_timeseries_pct['WA'].mean(axis=1).cumsum().plot(grid = True,
#         style = "-o",
#         figsize = (14,7),
#         linewidth = 0.9)
zhvi_timeseries_pct.groupby(level='Metro',axis=1).mean().cumsum()
# Out:
# Metro       Abilene, TX  Akron, OH  Albany-Lebanon, OR  \
# 2000-01-31          NaN        NaN                 NaN
# 2000-02-29          NaN   0.004221                 NaN
# 2000-03-31          NaN   0.005554                 NaN
# 2000-04-30          NaN   0.011225                 NaN
# 2000-05-31          NaN   0.016414                 NaN
# ...                 ...        ...                 ...
# 2022-06-30     0.584761   0.295222            0.798875
# 2022-07-31     0.590330   0.303687            0.798141
# 2022-08-31     0.593760   0.309701            0.798926
# 2022-09-30     0.599404   0.314684            0.800464
# 2022-10-31     0.600985   0.322266            0.806071
#
# Metro       Albany-Schenectady-Troy, NY  Albuquerque, NM  \
# 2000-01-31                          NaN              NaN
# 2000-02-29                     0.004392              NaN
# 2000-03-31                     0.004342              NaN
# 2000-04-30                     0.009316              NaN
# 2000-05-31                     0.011844              NaN
# ...                                 ...              ...
# 2022-06-30                     0.825078         0.767597
# 2022-07-31                     0.830696         0.773293
# 2022-08-31                     0.836056         0.778636
# 2022-09-30                     0.843360         0.780805
# 2022-10-31                     0.850740         0.785405
#
# Metro       Allentown-Bethlehem-Easton, PA-NJ  Altoona, PA  Ames, IA  \
# 2000-01-31                                NaN          NaN       NaN
# 2000-02-29                           0.007419    -0.000538       NaN
# 2000-03-31                           0.011486    -0.001130       NaN
# 2000-04-30                           0.018239     0.000612       NaN
# 2000-05-31                           0.019898     0.004534       NaN
# ...                                       ...          ...       ...
# 2022-06-30                           0.880329     0.531964  0.468031
# 2022-07-31                           0.888249     0.537126  0.472153
# 2022-08-31                           0.897131     0.538648  0.477854
# 2022-09-30                           0.906687     0.539510  0.486704
# 2022-10-31                           0.914912     0.542117  0.492387
#
# Metro       Anchorage, AK  Ann Arbor, MI  ...  Whitewater, WI  \
# 2000-01-31            NaN            NaN  ...             NaN
# 2000-02-29      -0.001823       0.002928  ...             NaN
# 2000-03-31      -0.001187       0.006415  ...             NaN
# 2000-04-30      -0.002377       0.012926  ...             NaN
# 2000-05-31      -0.000218       0.021369  ...             NaN
# ...                   ...            ...  ...             ...
# 2022-06-30       0.868466       0.795195  ...        0.807299
# 2022-07-31       0.893035       0.798367  ...        0.819055
# 2022-08-31       0.910316       0.798342  ...        0.825113
# 2022-09-30       0.922042       0.798086  ...        0.828824
# 2022-10-31       0.924238       0.801426  ...        0.840026
#
# Metro       Wichita Falls, TX  Wichita, KS  Wilmington, NC  Winston-Salem, NC  \
# 2000-01-31                NaN          NaN             NaN                NaN
# 2000-02-29                NaN          NaN             NaN           0.007095
# 2000-03-31                NaN          NaN             NaN           0.009830
# 2000-04-30                NaN          NaN             NaN           0.017120
# 2000-05-31                NaN          NaN             NaN           0.019934
# ...                       ...          ...             ...                ...
# 2022-06-30           0.599743     0.552780        0.810427           0.694197
# 2022-07-31           0.616240     0.562952        0.823712           0.710918
# 2022-08-31           0.630584     0.569476        0.834285           0.724304
# 2022-09-30           0.635418     0.577568        0.836897           0.731284
# 2022-10-31           0.641022     0.582609        0.843483           0.740653
#
# Metro       Worcester, MA-CT  Yakima, WA  York-Hanover, PA  \
# 2000-01-31               NaN         NaN               NaN
# 2000-02-29          0.002409         NaN          0.002728
# 2000-03-31          0.005816         NaN          0.004740
# 2000-04-30          0.012976         NaN          0.009049
# 2000-05-31          0.021298         NaN          0.009815
# ...                      ...         ...               ...
# 2022-06-30          0.905524    0.990621          0.709141
# 2022-07-31          0.904311    0.990949          0.714954
# 2022-08-31          0.902102    0.991057          0.717584
# 2022-09-30          0.902016    0.990583          0.720116
# 2022-10-31          0.903346    0.994698          0.722414
#
# Metro       Youngstown-Warren-Boardman, OH-PA  Yuma, AZ
# 2000-01-31                                NaN       NaN
# 2000-02-29                           0.002200       NaN
# 2000-03-31                           0.000965       NaN
# 2000-04-30                          -0.000657       NaN
# 2000-05-31                          -0.003738       NaN
# ...                                       ...       ...
# 2022-06-30                           0.194097  0.887665
# 2022-07-31                           0.190739  0.896249
# 2022-08-31                           0.190832  0.902914
# 2022-09-30                           0.196774  0.904608
# 2022-10-31                           0.205538  0.914031
#
# [274 rows x 301 columns]

# %%
# Plot accumulated returns
def plot_top_accum(pct_returns, time_years, regions_count):
    pct_returns.iloc[-time_years*12:].cumsum().sort_values(by=pct_returns.index[-1],axis=1,ascending=False).iloc[:,:regions_count].plot(
        grid = True,
        style = "-o",
        figsize = (14,7),
        linewidth = 0.9
    )

plot_top_accum(zhvi_timeseries_pct[['CA']].groupby(level='Metro',axis=1).mean(), 10, 10)

# %%
# Plot accumulated returns
def plot_top_accum(pct_returns, time_years, regions_count):
    pct_returns.iloc[-time_years*12:].cumsum().sort_values(by=pct_returns.index[-1],axis=1,ascending=False).iloc[:,:regions_count].plot(
        grid = True,
        style = "-o",
        figsize = (14,7),
        linewidth = 0.5
    )

plot_top_accum(zhvi_timeseries_pct[['CA']], 2, 7)

# %%
zhvi_timeseries_pct.groupby(level='Metro',axis=1).mean().cumsum()
# Out:
# Metro       Abilene, TX  Akron, OH  Albany-Lebanon, OR  \
# 2022-10-31    -0.007480            NaN     -0.001263
#
# [240 rows x 2898 columns]

# %% [markdown]
# ## Analysis at the State level. First itemize the subcateogries

# %%
ca_zhvi_timeseries_pct = zhvi_timeseries_pct['CA'].loc['2021':'2022']

# %%
ca_zhvi_timeseries_pct.columns = ca_zhvi_timeseries_pct.columns.remove_unused_levels()

# %%
zhvi_timeseries_pct.columns.levshape
# Out:
# (51, 301, 418, 883, 16642)

# %%
ca_zhvi_timeseries_pct.columns.levshape
# Out:
# (19, 29, 116, 2029)

# %%
ca_zhvi_timeseries_pct.columns.names
# Out:
# FrozenList(['Metro', 'CountyName', 'City', 'RegionName'])

# %%
# Option 1
set(ca_zhvi_timeseries_pct.columns.levels[0].values)
# Option 2
set(zhvi_timeseries_pct['CA'].columns.remove_unused_levels().levels[0].values)
# Out:
# {'Bakersfield, CA',
#  'Chico, CA',
#  'Eureka-Arcata, CA',
#  'Fresno, CA',
#  'Los Angeles-Long Beach-Anaheim, CA',
#  'Merced, CA',
#  'Napa, CA',
#  'Oxnard-Thousand Oaks-Ventura, CA',
#  'Riverside-San Bernardino-Ontario, CA',
#  'Sacramento-Roseville-Folsom, CA',
#  'Salinas, CA',
#  'San Diego-Chula Vista-Carlsbad, CA',
#  'San Francisco-Oakland-Berkeley, CA',
#  'San Jose-Sunnyvale-Santa Clara, CA',
#  'Santa Maria-Santa Barbara, CA',
#  'Santa Rosa-Petaluma, CA',
#  'Stockton, CA',
#  'Vallejo, CA',
#  'Visalia, CA'}

# %%
set(ca_zhvi_timeseries_pct.columns.levels[0])
# Out:
# {'Bakersfield, CA',
#  'Chico, CA',
#  'Eureka-Arcata, CA',
#  'Fresno, CA',
#  'Los Angeles-Long Beach-Anaheim, CA',
#  'Merced, CA',
#  'Napa, CA',
#  'Oxnard-Thousand Oaks-Ventura, CA',
#  'Riverside-San Bernardino-Ontario, CA',
#  'Sacramento-Roseville-Folsom, CA',
#  'Salinas, CA',
#  'San Diego-Chula Vista-Carlsbad, CA',
#  'San Francisco-Oakland-Berkeley, CA',
#  'San Jose-Sunnyvale-Santa Clara, CA',
#  'Santa Maria-Santa Barbara, CA',
#  'Santa Rosa-Petaluma, CA',
#  'Stockton, CA',
#  'Vallejo, CA',
#  'Visalia, CA'}

# %%
SDMetro = ca_zhvi_timeseries_pct[ca_zhvi_timeseries_pct.columns.levels[0].values[2]]
SDMetro.columns = SDMetro.columns.remove_unused_levels()

# %%
SDMetro.columns.levshape
# Out:
# (1, 7, 198)

# %%
set(SDMetro.columns.levels[0].values)
# Out:
# {'San Diego County'}

# %%
plot_top_accum(SDMetro['San Diego County'].groupby(level='City',axis=1).mean(), 3, 15)

# %%
plot_top_accum(zhvi_timeseries_pct['CA','San Diego-Chula Vista-Carlsbad, CA','San Diego County','Chula Vista'],3,15)
# Out:
# /var/folders/dz/2jdnkp3541v0nxf__ztf1nw80000gn/T/ipykernel_88972/2731105828.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   plot_top_accum(zhvi_timeseries_pct['CA','San Diego-Chula Vista-Carlsbad, CA','San Diego County','Chula Vista'],3,15)
